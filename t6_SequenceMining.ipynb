# %% [markdown]
# # Sequence Mining

# %% [markdown]
# Implementazione del **Sequence Mining**.

# %%
import nbimporter
from t1_ETLBasics import calories_to_df,sleep_to_df,exercise_to_df
from t3_TSToEvents import calories_to_events, sleep_to_events,exercise_to_events
from t4_FeatureRedaction import calories_kmeans, sleep_kmeans, exercise_kmeans
from t5_MakeTransactions import get_cal_transaction, get_sleep_transaction, get_exercise_transaction, get_master_transaction
import dateutil as du
from datetime import datetime
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
import re
from operator import itemgetter
PATH = '../../pmdata/'

# %%
cal_transaction = get_cal_transaction(calories_kmeans(calories_to_events(calories_to_df(PATH,[1,2])),4))
sleep_transaction = get_sleep_transaction(sleep_kmeans(sleep_to_events(sleep_to_df(PATH,[1,2])),4))
ex_transaction = get_exercise_transaction(exercise_kmeans(exercise_to_events(exercise_to_df(PATH,[1,2])),4))

# %%
main_transaction = get_master_transaction(cal_transaction,ex_transaction,sleep_transaction)

# %%
main_transaction
# Out:
# [[[datetime.datetime(2019, 11, 1, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 12, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 14, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 1, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 19, 0),
#    'exercise cluster: 0, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 1, 20, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 21, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 22, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 1, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 2, 0, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 0, 0),
#    'Sleep: weekend: True, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 2, 1, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 2, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 3, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 4, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 5, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 6, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 7, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 8, 0), 'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 9, 0), 'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 10, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 11, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 12, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 13, 0),
#    'exercise cluster: 0, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 2, 14, 0),
#    'calories cluster: 2, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 15, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 16, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 17, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 18, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 19, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 20, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 22, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 2, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 0, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 0, 0),
#    'Sleep: weekend: True, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 3, 1, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 2, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 3, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 4, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 5, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 6, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 7, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 8, 0), 'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 9, 0), 'calories cluster: 2, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 10, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 11, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 12, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 14, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 15, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 16, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 17, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 18, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 19, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 20, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 21, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 22, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 3, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 4, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 12, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 15, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 19, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 21, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 4, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 4, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 0, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 5, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 16, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 19, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 5, 20, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 5, 22, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Run'],
#   [datetime.datetime(2019, 11, 5, 23, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 0, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 6, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 15, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 19, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 6, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 6, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 7, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 15, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 19, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 7, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 8, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 15, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 15, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 8, 16, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 21, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 8, 23, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 9, 0, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 0, 0),
#    'Sleep: weekend: True, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 9, 1, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 2, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 3, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 4, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 5, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 6, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 6, 0),
#    'exercise cluster: 0, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 9, 7, 0), 'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 8, 0), 'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 9, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 10, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 11, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 12, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 14, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 15, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 16, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 17, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 18, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 19, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 20, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 21, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 22, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 9, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 0, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 0, 0),
#    'Sleep: weekend: True, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 10, 1, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 2, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 3, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 4, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 5, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 6, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 7, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 7, 0),
#    'exercise cluster: 0, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 10, 8, 0),
#    'calories cluster: 2, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 9, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 10, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 11, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 12, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 14, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 15, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 16, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 17, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 18, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 19, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 20, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 22, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 10, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 11, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 11, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 15, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 18, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 20, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Run'],
#   [datetime.datetime(2019, 11, 11, 21, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 11, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 12, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 5, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 12, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 19, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 21, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 12, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 13, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 16, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 17, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 19, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 13, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 14, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 9, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 11, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 12, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 15, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 14, 16, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 20, 0),
#    'exercise cluster: 0, part day: Sera, Activity: Sport'],
#   [datetime.datetime(2019, 11, 14, 21, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 21, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 14, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 14, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 0, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 15, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 8, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 15, 9, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 10, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 15, 11, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 14, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 14, 0),
#    'exercise cluster: 0, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 15, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 19, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 22, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 15, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 16, 0, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 0, 0),
#    'Sleep: weekend: True, efficiency: Media-Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 16, 1, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 2, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 3, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 4, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 5, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 6, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 6, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 16, 7, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 8, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 9, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 10, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 11, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 12, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 14, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 14, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Sport'],
#   [datetime.datetime(2019, 11, 16, 15, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 16, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 17, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 18, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 18, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 16, 19, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 20, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 22, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 16, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 0, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 0, 0),
#    'Sleep: weekend: True, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 17, 1, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 2, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 3, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 4, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 5, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 6, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 7, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 8, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 8, 0),
#    'exercise cluster: 0, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 11, 17, 9, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 10, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 11, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 12, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 14, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 15, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 16, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 17, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 18, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 19, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 20, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 22, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 11, 17, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 11, 18, 0, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 18, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 15, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 16, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 17, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 20, 0),
#    'exercise cluster: 0, part day: Sera, Activity: Treadmill'],
#   [datetime.datetime(2019, 11, 18, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 22, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 18, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 0, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 19, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 10, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 15, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 16, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 19, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 21, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 21, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 11, 19, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 19, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 11, 20, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 7, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 8, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 11, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 12, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 18, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 22, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 20, 23, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 21, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 9, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 12, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 15, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 11, 21, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 19, 0),
#    'exercise cluster: 2, part day: Sera, Activity: Sport'],
#   [datetime.datetime(2019, 11, 21, 20, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 21, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 22, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 11, 21, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 22, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 22, 0, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 6'],
#   [datetime.datetime(2019, 11, 22, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 22, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 11, 22, 3, 0),
#    'calories cluster: 1, weekend: False'],
# ...
#   [datetime.datetime(2019, 12, 1, 18, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 19, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 20, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 22, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 23, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 1, 23, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 1, 23, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 2, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 6, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 7, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 12, 2, 8, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 9, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 11, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 14, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 12, 2, 14, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Sport'],
#   [datetime.datetime(2019, 12, 2, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 15, 0),
#    'exercise cluster: 0, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 12, 2, 16, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 18, 0),
#    'exercise cluster: 2, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 12, 2, 19, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 20, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 21, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 2, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 3, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 7, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 12, 3, 8, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 10, 0),
#    'exercise cluster: 0, part day: Mattina, Activity: Weights'],
#   [datetime.datetime(2019, 12, 3, 11, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 14, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 14, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 12, 3, 15, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 17, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 21, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 22, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 3, 23, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 4, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 6, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 8, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 13, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 14, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 15, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 17, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 19, 0),
#    'exercise cluster: 0, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 12, 4, 20, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 21, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 4, 23, 0),
#    'Sleep: weekend: False, efficiency: Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 5, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 6, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 12, 5, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 8, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 10, 0),
#    'exercise cluster: 0, part day: Mattina, Activity: Weights'],
#   [datetime.datetime(2019, 12, 5, 11, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 12, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 13, 0),
#    'exercise cluster: 3, part day: Pomeriggio, Activity: Run'],
#   [datetime.datetime(2019, 12, 5, 14, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 15, 0),
#    'calories cluster: 2, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 16, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 17, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 19, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 20, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 21, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 5, 23, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 4'],
#   [datetime.datetime(2019, 12, 6, 0, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 1, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 2, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 3, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 4, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 5, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 5, 0),
#    'Sleep: weekend: False, efficiency: Media-Alta, durationSleep: 1'],
#   [datetime.datetime(2019, 12, 6, 6, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 7, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 7, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Walk'],
#   [datetime.datetime(2019, 12, 6, 8, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 9, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 10, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 11, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 12, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 13, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 14, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 14, 0),
#    'exercise cluster: 0, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 12, 6, 15, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 16, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 16, 0),
#    'exercise cluster: 1, part day: Pomeriggio, Activity: Walk'],
#   [datetime.datetime(2019, 12, 6, 17, 0),
#    'calories cluster: 3, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 18, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 19, 0),
#    'calories cluster: 0, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 20, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 21, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 22, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 23, 0),
#    'calories cluster: 1, weekend: False'],
#   [datetime.datetime(2019, 12, 6, 23, 0),
#    'Sleep: weekend: True, efficiency: Media-Alta, durationSleep: 7'],
#   [datetime.datetime(2019, 12, 7, 0, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 1, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 2, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 3, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 4, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 5, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 6, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 7, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 8, 0), 'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 8, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Aerobic Workout'],
#   [datetime.datetime(2019, 12, 7, 9, 0), 'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 9, 0),
#    'exercise cluster: 3, part day: Mattina, Activity: Sport'],
#   [datetime.datetime(2019, 12, 7, 10, 0),
#    'calories cluster: 2, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 10, 0),
#    'exercise cluster: 1, part day: Mattina, Activity: Aerobic Workout'],
#   [datetime.datetime(2019, 12, 7, 11, 0),
#    'calories cluster: 2, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 12, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 13, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 14, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 15, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 16, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 17, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 18, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 18, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 12, 7, 19, 0),
#    'calories cluster: 3, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 20, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 21, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 22, 0),
#    'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 7, 22, 0),
#    'exercise cluster: 1, part day: Sera, Activity: Walk'],
#   [datetime.datetime(2019, 12, 7, 23, 0),
#    'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 8, 0, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 8, 1, 0), 'calories cluster: 0, weekend: True'],
#   [datetime.datetime(2019, 12, 8, 2, 0), 'calories cluster: 1, weekend: True'],
#   [datetime.datetime(2019, 12, 8, 2, 0),
#    'Sleep: weekend: True, efficiency: Media-Alta, durationSleep: 7'],
#   ...]]

# %%
def get_trans(trans):
    """Funzione che crea una lista contenente le transazioni raggruppate per data
    
    Parametri: 
    - trans: lista contenente le transazioni
    
    Ritorna:
    - lista che contiene le transazioni raggruppate per data e ordinate"""
    groupedByDay={}
    for t in trans:
        if t[0].date() in groupedByDay:
            groupedByDay[t[0].date()].append(t)
        else:
            groupedByDay[t[0].date()]=[t]
    return list(groupedByDay.values())

# %%
def get_list_m_transaction(main_transaction):
    """Funzione che ritorna una lista in cui un elemento
    è la lista delle transazioni raggruppate e ordinate 
    richiamando la funzione 'get_trans'.
    
    Parametri:
    - lista in cui l'i-esimo elemento è la lista di transazioni dell'i-esimo partecipante
    
    Ritorna:
    - lista in cui ogni elemento è la lista di transazioni ordinata e raggruppata per timestamp per l'i-esimo partecipante."""
    m_transaction = []
    for i in range(len(main_transaction)):
        m_transaction.append(get_trans(main_transaction[i]))
    return m_transaction

# %%
m_transaction = get_list_m_transaction(main_transaction)

# %%
m_transaction

# %%
def get_transaction(m_transaction):
    """Funzione che genera una lista di liste in cui un elemento è la lista completa delle transazioni per ogni partecipante.
        Viene eliminato il timestamp.
    
    Parametri:
    - m_transaction: lista delle transazioni in cui ho ancora il timestamp
    
    Ritorna:
    - transactions: lista di liste che contiene la lista delle transazioni per ogni partecipante senza timestamp."""
    transactions = []
    for m in m_transaction:
        transactions.append([ [i[1] for i in tr] for tr in m])
    return transactions

# %%
transactions = get_transaction(m_transaction)

# %%
transactions[0]

# %% [markdown]
# Implementazione utilizzando una struttura ad albero.

# %%
def extract_unique_value(seq):  
    """Funzione che estrae i valori presenti nella seq
    
    Parametri:
    - seq: sequenza di transazioni
    
    Ritorna:
    - lista di elementi nella sequenza senza ripetizioni"""
    a = [] 
    for s in seq:
        a+=list(set(s))
    return list(set(a))

# %%
def get_dictionary(trans):
    """ Funzione che genera il Dizionario per la nostra analisi
    
    Parametri: 
    - trans: lista delle transazioni
    
    Ritorna:
    - dictionary: lista degli elementi senza duplicati"""
    dictionary = extract_unique_value(trans)
    dictionary.sort(reverse=True)
    return dictionary

# %%
def get_list_dictionaries(transactions):
    """ Funziona che genera una lista di liste in cui ogni elemento contiene il dizionario dell'i-esimo
    partecipante.
    
    Parametri:
    - transactions
    
    Ritorna:
    - dictionaries: lista di liste"""
    dictionaries = []
    for i in range(len(transactions)):
        d = get_dictionary(transactions[i])
        dictionaries.append(d)
    return dictionaries

# %%
dictionaries = get_list_dictionaries(transactions)

# %%
dictionaries[1]

# %% [markdown]
# Definire il **Separatore**:

# %%
SEP = '<!>'

# %%
def get_confidence(arr,trans,supp):
    """Funzione che calcola la confidenza di una sequenza:
    per esempio se ho [A,B,C,D] calcola la confudenza di {A,B,C} -> {D}
    
    Parametri:
    - arr: sequenza
    - trans: lista
    - supp: supporto di arr
    
    Ritorna:
    - la confidenza della sequenza"""
    antecedent = arr
    if(len(arr)>1):
        antecedent = arr[:-1]
    #sup_cons = get_supp(consequent,trans,1)
    sup_ant = get_supp(antecedent,trans)
    return supp/sup_ant

# %%
def get_supp(d,t):
    """Funzione che calcola il supporto di una sequenza
    
    Parametri:
    - d: sequenza
    - t: transazioni
    
    Ritorna:
    - il supporto della sequenza sulla transazione"""
    c=0
    for tr in t:
        ttext = SEP + (SEP+SEP).join(tr) + SEP
        preg = '.*'.join([ re.escape(i) for i in d])
        search = re.search(preg, ttext)
        c = c + 1 if search else c
    return c/len(t)

# %%
def extract_patterns_simple(t, minsup, minlen, maxlen,arr,dic):
    """ Funzione che stampa le sequenze che hanno un supporto maggiore del minsup e di lunghezza 
    tra minlen e maxlen.
    
    Parametri:
    - t: transazioni
    - minsup: supporto minimo
    - minlen: minima lunghezza della sequenza
    - maxlen: massima lunghezza della sequenza
    - arr: sequenza iniziale
    - dic: dizionario 
    
    Ritorna:
    - None"""
    for d in dic:
        arr.append(d)
        support = get_supp(arr,t)
        
        if  support >= minsup:
            if(len(arr) >= minlen and len(arr) <= maxlen):
                #test confidenza qua
                print(f'{arr}: Support: {support}')
                
            if(len(arr)<=maxlen):
                extract_patterns_simple(t, minsup, minlen, maxlen,arr,dic)
        arr.pop()

# %%
#extract_patterns_simple(transactions,0.2,2,4,[],dictionary)

# %%
for i in range(len(transactions)):
    print(f"\nPARTECIPANTE {i+1}\n*****************************\n\n")
    extract_patterns_simple(transactions[i],0.5,2,4,[],dictionaries[i])

# %%
def check_confidence(conf,minconf):
    """ Controlla se la confidenza è minore della confidenza minima
    
    Parametri:
    - conf: confidenza trovata
    - minconf: minima confidenza
    
    Ritorna:
    - True se la conf è minore, False altrimenti."""
    if conf<minconf:
        return True
    return False

# %%
def extract_patterns(t, minsup, minconf, minlen, maxlen,arr,dic,i):
    """ Funzione che estrae i pattern che hanno un supporto maggiore del minsup e una confidenza
    maggiore delle minconf e di lunghezza tra minlen e maxlen. Salvo in un file i pattern.
    
    Parametri:
    - t: transazioni
    - minsup: supporto minimo
    - minconf: minima confidenza
    - minlen: minima lunghezza della sequenza
    - maxlen: massima lunghezza della sequenza
    - arr: sequenza iniziale
    - dic: dizionario 
    
    Ritorna:
    - None"""
    for d in dic:
        arr.append(d)
        support = get_supp(arr,t)
        
        if  support >= minsup:
            if(len(arr) >= minlen and len(arr) <= maxlen):
                #test confidenza qua
                #print(f'{arr}: Support: {support}')
                
                confidence= get_confidence(arr,t,support)
                if(check_confidence(confidence,minconf)):
                    print('NESSUNA REGOLA')
                else:
                    print(f'{arr}: {confidence}')
                    # Qui si deve spostare la freccia a sinistra e ricalcolare la confidenza
                    #conf,ant = get_confidence(ant[:-1],t,get_supp(ant,t))
                    #check_confidence(conf,min_conf)
                    with open("./output"+"p{:02d}".format(i)+".txt", "a") as file:
                        for a in arr:
                            file.write(a+ "<!>")
                        file.write("\n")
            if(len(arr)<=maxlen):
                extract_patterns(t, minsup,minconf, minlen, maxlen,arr,dic,i)
        arr.pop()

# %%
#extract_patterns(transactions,0.2,0.9,2,4,[],dictionary)
for i in range(len(transactions)):
    print(f"\nPARTECIPANTE {i+1}\n*****************************\n\n")
    extract_patterns(transactions[i],0.5,0.96,2,4,[],dictionaries[i],i)
# Out:
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9722222222222222
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False']: 0.962962962962963
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 0.9807692307692307
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9722222222222222
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False']: 0.962962962962963
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9722222222222222
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: 0.962962962962963
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 0.9907407407407408
# ['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False']: 0.962962962962963
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9907407407407408
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: 0.9722222222222222
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9714285714285714
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 0.9619047619047619
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 0.9907407407407408
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9719626168224299
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: 0.9626168224299065
#
# PARTECIPANTE 2
# *****************************
#
#
# ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9896907216494845
# ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9895833333333334
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9759036144578315
# ['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9876543209876542
# ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 0.9883720930232559
# ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9882352941176471
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9896907216494845
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9895833333333334
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9759036144578315
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 0.9883720930232559
# ['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9882352941176471
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9896907216494845
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 0.9883720930232559
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9805825242718446
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9888888888888889
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 0.9880952380952379
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9805825242718446
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.979381443298969
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 0.9888888888888889
# ['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9887640449438203
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 0.9880952380952379
# ['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9879518072289157
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9805825242718446
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 0.9900990099009902
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.968421052631579
# NESSUNA REGOLA
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.979381443298969
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: 1.0
# NESSUNA REGOLA
# ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: 0.9879518072289157

# %%
def get_pattern(i):
    """Funzione che legge i file contenenti i pattern e li salva in una lista.
    
    Parametri:
    - i: contatore per leggere il file corretto
    
    Ritorna:
    -patterns1: lista dei pattern"""
    with open("./output"+ "p{:02d}".format(i)+".txt","r") as in_file:
        patterns = in_file.readlines()
    patt = []
    for p in patterns:
        patt.append(p.rstrip("\n"))
    patterns1 = []
    for p1 in patt:
        patterns1.append(p1.split("<!>"))
    for p2 in patterns1:
        p2.pop()
    return patterns1

# %%
def get_list_patterns(transactions):
    """Funzione che genera la lista di liste contenente la lista di patterns per ogni partecipante.
    
    Parametri:
    - transactions: transazioni
    
    Ritorna:
    - patterns: lista di liste"""
    patterns = []
    for i in range(len(transactions)):
        patterns.append(get_pattern(i))
    return patterns

# %%
patterns = get_list_patterns(transactions)

# %%
def get_association_rule(p,t,ant,i):
    """Funzione che genera le association rule e le stampa.
    
    Parametri:
    - p: lista dei pattern
    - t: transazioni
    - ant: antecedente
    - i: contatore
    
    Ritorna:
    - None"""
    conf = get_supp(p,t)/get_supp(ant,t)
    if(check_confidence(conf,0.96)):
        if(len(p[0:i+1])< len(p)):
            get_association_rule(p,t,p[0:i+1],i+1)
        else: 
            print(f'NESSUNA REGOLA per {p}')
            #with open("./rules"+"p{:02d}".format(i)+".txt", "a") as file:
            #    file.write(f'NESSUNA REGOLA per {p}\n')

    else:
        print(f'Rule:{ant} -> {p[i-1:-1]}: confidence {conf}')
        with open("./rules.txt", "a") as file:
                file.write(f'Rule:{ant} -> {p[i-1:-1]}: confidence {conf}\n')

# %%
def get_rules(patterns,tr):
    """Funzione che richiama la funzione che genera le regole per ogni partecipante.
    
    Parametri:
    - patterns: lista di pattern
    - tr: lista di transazioni"""
    for p in patterns:
        #richiamare una funzione che mi sposta la freccia e calcola la confidenza della regola
        ant = []
        ant.append(p[0])
        get_association_rule(p,tr,ant,1)

# %%
from os.path import exists
import os

# %%
# Eseguire per stampare e generare le regole
if(exists("./rules.txt")):
    os.remove("rules.txt")
for i in range(len(patterns)):
    print(f"\n\nREGOLE PER PARTECIPANTE {i+1}\n")
    with open("./rules.txt", "a") as file:
        file.write(f"\n\nREGOLE PER PARTECIPANTE {i+1}\n")
    get_rules(patterns[i],transactions[i])
# Out:
# REGOLE PER PARTECIPANTE 1
#
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.980952380952381
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9611650485436892
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9807692307692307
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9714285714285714
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9619047619047619
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9626168224299065
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.980952380952381
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9611650485436892
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9807692307692307
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9714285714285714
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9619047619047619
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9626168224299065
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.980952380952381
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9611650485436892
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9807692307692307
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9714285714285714
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9619047619047619
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9626168224299065
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.980952380952381
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9611650485436892
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9807692307692307
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9714285714285714
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9619047619047619
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9626168224299065
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.980952380952381
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9611650485436892
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9807692307692307
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9722222222222222
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9714285714285714
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9619047619047619
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.9907407407407408
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False']: confidence 0.962962962962963
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9626168224299065
#
#
# REGOLE PER PARTECIPANTE 2
#
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.963855421686747
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.963855421686747
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9777777777777779
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9761904761904762
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.970873786407767
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.968421052631579
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9879518072289157
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.963855421686747
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9777777777777779
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9761904761904762
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.970873786407767
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.968421052631579
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9879518072289157
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.963855421686747
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9777777777777779
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9761904761904762
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.970873786407767
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.968421052631579
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9879518072289157
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.963855421686747
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9759036144578315
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9767441860465117
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9896907216494845
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9883720930232559
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False'] -> ['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 1.0
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 0.9888888888888889
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9777777777777779
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 0.9880952380952379
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9761904761904762
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 3, weekend: False'] -> ['calories cluster: 3, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 2, weekend: False'] -> ['calories cluster: 2, weekend: False']: confidence 1.0
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.9805825242718446
# Rule:['calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.970873786407767
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.968421052631579
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False', 'calories cluster: 1, weekend: False']: confidence 0.979381443298969
# Rule:['calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False', 'calories cluster: 0, weekend: False'] -> ['calories cluster: 0, weekend: False']: confidence 0.9879518072289157
